# %% [markdown]
# # Colab

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/uni_bonn/nlp/final_project
# Out:
# /content/drive/MyDrive/uni_bonn/nlp/final_project

# %% [markdown]
# # Install modules

# %%
# !pip install datasets
# !pip install 'transformers[torch]'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 5.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import modules

# %%
import pandas as pd
from datasets import load_dataset
from transformers import AutoTokenizer
import numpy as np
import json

# %% [markdown]
# # Create JSON files (not neccessary to do this)

# %% [markdown]
# ## Create json file for train set

# %%
train_ds = list()

# %%
f1 = open("./dataset/GYAFC_Corpus/Family_Relationships/train/informal", 'r')
f2 = open("./dataset/GYAFC_Corpus/Family_Relationships/train/formal", 'r')

id = 0

while True:
  line1 = f1.readline().rstrip()
  line2 = f2.readline().rstrip()
  if not line1:
    break

  train_ds.append(
      {
          'id':id,
          'topic':'Family_Relationships',
          'transformation':{
              'informal': "Write this more formally: " + line1,
              'formal.ref0':line2,
              'formal.ref1':"",
              'formal.ref2':"",
              'formal.ref3':"",
          }
      }
  )  # adding a row

  id += 1

# %%
f1 = open("./dataset/GYAFC_Corpus/Entertainment_Music/train/informal", 'r')
f2 = open("./dataset/GYAFC_Corpus/Entertainment_Music/train/formal", 'r')

while True:
  line1 = f1.readline().rstrip()
  line2 = f2.readline().rstrip()
  if not line1:
    break

  train_ds.append(
      {
          'id':id,
          'topic':'Entertainment_Music',
          'transformation':{
              'informal':"Write this more formally: " + line1,
              'formal.ref0':line2,
              'formal.ref1':"",
              'formal.ref2':"",
              'formal.ref3':"",
          }
      }
  )

  id += 1

# %%
with open("./dataset/GYAFC_Corpus/data_train_coedit.json", 'w') as f:
  json.dump(train_ds, f, ensure_ascii=False)

# %% [markdown]
# ## Create json file for validation set

# %%
val_ds = list()

# %%
f1 = open("./dataset/GYAFC_Corpus/Family_Relationships/tune/informal", 'r')
f2 = open("./dataset/GYAFC_Corpus/Family_Relationships/tune/formal.ref0", 'r')
f3 = open("./dataset/GYAFC_Corpus/Family_Relationships/tune/formal.ref1", 'r')
f4 = open("./dataset/GYAFC_Corpus/Family_Relationships/tune/formal.ref2", 'r')
f5 = open("./dataset/GYAFC_Corpus/Family_Relationships/tune/formal.ref3", 'r')

id = 0

while True:
  line1 = f1.readline().rstrip()
  line2 = f2.readline().rstrip()
  line3 = f3.readline().rstrip()
  line4 = f4.readline().rstrip()
  line5 = f5.readline().rstrip()
  if not line1:
    break

  val_ds.append(
      {
          'id':id,
          'topic':'Family_Relationships',
          'transformation':{
              'informal': "Write this more formally: " + line1,
              'formal.ref0':line2,
              'formal.ref1':line3,
              'formal.ref2':line4,
              'formal.ref3':line5,
          }
      })  # adding a row
  id += 1

# %%
f1 = open("./dataset/GYAFC_Corpus/Entertainment_Music/tune/informal", 'r')
f2 = open("./dataset/GYAFC_Corpus/Entertainment_Music/tune/formal.ref0", 'r')
f3 = open("./dataset/GYAFC_Corpus/Entertainment_Music/tune/formal.ref1", 'r')
f4 = open("./dataset/GYAFC_Corpus/Entertainment_Music/tune/formal.ref2", 'r')
f5 = open("./dataset/GYAFC_Corpus/Entertainment_Music/tune/formal.ref3", 'r')

while True:
  line1 = f1.readline().rstrip()
  line2 = f2.readline().rstrip()
  line3 = f3.readline().rstrip()
  line4 = f4.readline().rstrip()
  line5 = f5.readline().rstrip()
  if not line1:
    break

  val_ds.append(
      {
          'id':id,
          'topic':'Entertainment_Music',
          'transformation':{
              'informal': "Write this more formally: " + line1,
              'formal.ref0':line2,
              'formal.ref1':line3,
              'formal.ref2':line4,
              'formal.ref3':line5,
          }
      }) # adding a row
  id += 1

# %%
with open("./dataset/GYAFC_Corpus/data_val_coedit.json", 'w') as f:
  json.dump(val_ds, f, ensure_ascii=False)

# %% [markdown]
# ## Create json file for test set

# %%
test_ds = list()

# %%
f1 = open("./dataset/GYAFC_Corpus/Family_Relationships/test/informal", 'r')
f2 = open("./dataset/GYAFC_Corpus/Family_Relationships/test/formal.ref0", 'r')
f3 = open("./dataset/GYAFC_Corpus/Family_Relationships/test/formal.ref1", 'r')
f4 = open("./dataset/GYAFC_Corpus/Family_Relationships/test/formal.ref2", 'r')
f5 = open("./dataset/GYAFC_Corpus/Family_Relationships/test/formal.ref3", 'r')

id = 0

while True:
  line1 = f1.readline().rstrip()
  line2 = f2.readline().rstrip()
  line3 = f3.readline().rstrip()
  line4 = f4.readline().rstrip()
  line5 = f5.readline().rstrip()
  if not line1:
    break

  test_ds.append(
      {
          'id':id,
          'topic':'Family_Relationships',
          'transformation':{
              'informal': "Write this more formally: " + line1,
              'formal.ref0':line2,
              'formal.ref1':line3,
              'formal.ref2':line4,
              'formal.ref3':line5,
          }
      })  # adding a row
  id += 1

# %%
f1 = open("./dataset/GYAFC_Corpus/Entertainment_Music/test/informal", 'r')
f2 = open("./dataset/GYAFC_Corpus/Entertainment_Music/test/formal.ref0", 'r')
f3 = open("./dataset/GYAFC_Corpus/Entertainment_Music/test/formal.ref1", 'r')
f4 = open("./dataset/GYAFC_Corpus/Entertainment_Music/test/formal.ref2", 'r')
f5 = open("./dataset/GYAFC_Corpus/Entertainment_Music/test/formal.ref3", 'r')

while True:
  line1 = f1.readline().rstrip()
  line2 = f2.readline().rstrip()
  line3 = f3.readline().rstrip()
  line4 = f4.readline().rstrip()
  line5 = f5.readline().rstrip()
  if not line1:
    break

  test_ds.append(
      {
          'id':id,
          'topic':'Entertainment_Music',
          'transformation':{
              'informal': "Write this more formally: " + line1,
              'formal.ref0':line2,
              'formal.ref1':line3,
              'formal.ref2':line4,
              'formal.ref3':line5,
          }
      })  # adding a row
  id += 1

# %%
with open("./dataset/GYAFC_Corpus/data_test_coedit.json", 'w') as f:
  json.dump(test_ds, f, ensure_ascii=False)

# %% [markdown]
# # Load dataset using Transformer datasets

# %%
data_files={
    "train":"./dataset/GYAFC_Corpus/data_train.json",
    "val":"./dataset/GYAFC_Corpus/data_val.json",
    "test":"./dataset/GYAFC_Corpus/data_test.json",
}

# %%
dataset = load_dataset("json", data_files=data_files)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating val split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['transformation', 'id', 'topic'],
#         num_rows: 104562
#     })
#     val: Dataset({
#         features: ['transformation', 'id', 'topic'],
#         num_rows: 5665
#     })
#     test: Dataset({
#         features: ['transformation', 'id', 'topic'],
#         num_rows: 2748
#     })
# })

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
def preprocess_function(examples, input_field="informal", target_field="formal.ref0"):
    inputs = [ex[input_field] for ex in examples["transformation"]]
    targets = [ex[target_field] for ex in examples["transformation"]]

    new_examples = tokenizer(
        inputs, text_target=targets, max_length=64, truncation=True, padding="max_length"
    )

    return new_examples

# %%
def create_multi_ref_dataset(dataset):
  for i, target_field in enumerate(['formal.ref0', 'formal.ref1', 'formal.ref2', 'formal.ref3']):
    new_dataset = preprocess_function(dataset, 'informal', target_field)
    dataset = dataset.add_column(f'labels_{i}', new_dataset['labels'])
    if i == 0:
      dataset = dataset.add_column('input_ids', new_dataset['input_ids'])
      dataset = dataset.add_column('token_type_ids', new_dataset['token_type_ids'])
      dataset = dataset.add_column('attention_mask', new_dataset['attention_mask'])

  return dataset

# %%
val_dataset = create_multi_ref_dataset(dataset['val'])
test_dataset = create_multi_ref_dataset(dataset['test'])

# %%
train_dataset = dataset['train'].map(
    preprocess_function,
    batched=True,
)
# Out:
# Map:   0%|          | 0/104562 [00:00<?, ? examples/s]

# %%
# test
tokenizer.convert_ids_to_tokens(val_dataset["labels_0"][40])
# Out:
# ['[CLS]',
#  'Both',
#  'of',
#  'you',
#  'need',
#  'to',
#  'end',
#  'this',
#  'relationship',
#  'completely',
#  'so',
#  'that',
#  'you',
#  'can',
#  'obtain',
#  'closure',
#  'and',
#  'move',
#  'on',
#  '.',
#  '[SEP]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]',
#  '[PAD]']
